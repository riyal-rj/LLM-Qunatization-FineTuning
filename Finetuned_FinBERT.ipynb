# %%
# !pip install transformers[torch] accelerate -U
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting transformers[torch]
#   Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 20.8 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.32.1-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.4)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->transformers[torch])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->transformers[torch])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->transformers[torch])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->transformers[torch])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->transformers[torch])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->transformers[torch])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->transformers[torch])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch])
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 63.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, transformers, accelerate
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.2
#     Uninstalling transformers-4.41.2:
#       Successfully uninstalled transformers-4.41.2
# Successfully installed accelerate-0.32.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 transformers-4.42.3

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1

# %%
from getpass import getpass
import os

os.environ['HF_TOKEN'] = getpass('Huggingface Access Token: ')
# Out:
# Huggingface Access Token: ··········

# %%
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, Trainer, TrainingArguments, AutoModelForSequenceClassification
import torch
from datasets import Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Load the FinBERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')
model = AutoModelForSequenceClassification.from_pretrained('ProsusAI/finbert', num_labels=3)  # Adjust the number of labels if needed
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
# Load dataset
df = pd.read_csv("all-data.csv")
df.head(4)
# Out:
#      result                                            content
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...

# %%
# Split dataset
df_train, df_test = train_test_split(df, stratify=df['result'], test_size=0.1, random_state=42)
df_train, df_val = train_test_split(df_train, stratify=df_train['result'], test_size=0.1, random_state=42)

# %%
# Prepare datasets for fine-tuning
dataset_train = Dataset.from_pandas(df_train)
dataset_val = Dataset.from_pandas(df_val)
dataset_test = Dataset.from_pandas(df_test)

# %%
# Tokenize datasets
def tokenize_data(example):
    return tokenizer(example['content'], truncation=True, padding='max_length', max_length=128)

# %%
dataset_train = dataset_train.map(tokenize_data, batched=True)
dataset_val = dataset_val.map(tokenize_data, batched=True)
dataset_test = dataset_test.map(tokenize_data, batched=True)
# Out:
# Map:   0%|          | 0/3924 [00:00<?, ? examples/s]
# Map:   0%|          | 0/437 [00:00<?, ? examples/s]
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]

# %%
model.config.id2label
# Out:
# {0: 'positive', 1: 'negative', 2: 'neutral'}

# %%
# Define a mapping for your labels
label_map = {'positive': 0, 'neutral': 2, 'negative': 1}

# Ensure the labels are in the correct format
def format_labels(example):
    example['labels'] = label_map[example['result']]
    return example

dataset_train = dataset_train.map(format_labels)
dataset_val = dataset_val.map(format_labels)
dataset_test = dataset_test.map(format_labels)
# Out:
# Map:   0%|          | 0/3924 [00:00<?, ? examples/s]
# Map:   0%|          | 0/437 [00:00<?, ? examples/s]
# Map:   0%|          | 0/485 [00:00<?, ? examples/s]

# %%
# Set the format of the datasets to PyTorch tensors
dataset_train.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
dataset_val.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
dataset_test.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %%
# Define a function to compute metrics based on predictions and labels
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {'accuracy': accuracy_score(labels, predictions)}

# %%
# Set up training arguments
training_args = TrainingArguments(
    output_dir='temp_output/',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    learning_rate=2e-5,
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
    num_train_epochs=5,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model='accuracy',
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# Initialize the Trainer with the model, training arguments, and datasets
trainer = Trainer(
    model=model,  # the Hugging Face Transformers model to be trained
    args=training_args,
    train_dataset=dataset_train,  # your training dataset
    eval_dataset=dataset_val,    # your validation dataset
    compute_metrics=compute_metrics,
)

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 4            |        cudaMalloc retries: 5         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |   1812 MiB |  14938 MiB | 174572 MiB | 172759 MiB |\n|       from large pool |   1810 MiB |  14932 MiB | 173893 MiB | 172082 MiB |\n|       from small pool |      2 MiB |     15 MiB |    679 MiB |    676 MiB |\n|---------------------------------------------------------------------------|\n| Active memory         |   1812 MiB |  14938 MiB | 174572 MiB | 172759 MiB |\n|       from large pool |   1810 MiB |  14932 MiB | 173893 MiB | 172082 MiB |\n|       from small pool |      2 MiB |     15 MiB |    679 MiB |    676 MiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |   1783 MiB |  14932 MiB | 174435 MiB | 172652 MiB |\n|       from large pool |   1780 MiB |  14926 MiB | 173757 MiB | 171976 MiB |\n|       from small pool |      2 MiB |     15 MiB |    678 MiB |    676 MiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  11372 MiB |  14972 MiB |  40300 MiB |  28928 MiB |\n|       from large pool |  11354 MiB |  14966 MiB |  40274 MiB |  28920 MiB |\n|       from small pool |     18 MiB |     18 MiB |     26 MiB |      8 MiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory | 119946 KiB | 409885 KiB |  25020 MiB |  24902 MiB |\n|       from large pool | 114248 KiB | 408996 KiB |  24293 MiB |  24182 MiB |\n|       from small pool |   5698 KiB |  12214 KiB |    726 MiB |    720 MiB |\n|---------------------------------------------------------------------------|\n| Allocations           |     820    |    1025    |    7577    |    6757    |\n|       from large pool |     304    |     380    |    3585    |    3281    |\n|       from small pool |     516    |     721    |    3992    |    3476    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     820    |    1025    |    7577    |    6757    |\n|       from large pool |     304    |     380    |    3585    |    3281    |\n|       from small pool |     516    |     721    |    3992    |    3476    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |     189    |     189    |     411    |     222    |\n|       from large pool |     180    |     180    |     398    |     218    |\n|       from small pool |       9    |       9    |      13    |       4    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      38    |      47    |    1501    |    1463    |\n|       from large pool |      22    |      28    |     581    |     559    |\n|       from small pool |      16    |      22    |     920    |     904    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='155' max='155' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [155/155 07:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.236492</td>
#       <td>0.922197</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.235939</td>
#       <td>0.919908</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.246495</td>
#       <td>0.922197</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.245337</td>
#       <td>0.924485</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>0.252270</td>
#       <td>0.926773</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=155, training_loss=0.14968849920457408, metrics={'train_runtime': 455.4957, 'train_samples_per_second': 43.074, 'train_steps_per_second': 0.34, 'total_flos': 1290571313955840.0, 'train_loss': 0.14968849920457408, 'epoch': 5.0})

# %%
model.eval()
trainer.predict(dataset_test).metrics
# Out:
# {'test_loss': 0.3323202431201935,
#  'test_accuracy': 0.8804123711340206,
#  'test_runtime': 3.369,
#  'test_samples_per_second': 143.961,
#  'test_steps_per_second': 1.187}

# %%
texts = list(df.content.values)

# %%
model_path='finbert-sentiment/'
# Save the model
trainer.model.save_pretrained(model_path)

# Save the tokenizer associated with the model
# Save the tokenizer
tokenizer.save_pretrained(model_path)
# Out:
# ('finbert-sentiment/tokenizer_config.json',
#  'finbert-sentiment/special_tokens_map.json',
#  'finbert-sentiment/vocab.txt',
#  'finbert-sentiment/added_tokens.json',
#  'finbert-sentiment/tokenizer.json')

# %%
from transformers import pipeline
senti=pipeline('sentiment-analysis', model=model_path, tokenizer=model_path)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
results=senti(texts)

# %%
results
# Out:
# [{'label': 'neutral', 'score': 0.9921261072158813},
#  {'label': 'neutral', 'score': 0.9574199318885803},
#  {'label': 'negative', 'score': 0.9884246587753296},
#  {'label': 'positive', 'score': 0.9856417775154114},
#  {'label': 'positive', 'score': 0.9815966486930847},
#  {'label': 'positive', 'score': 0.9822283387184143},
#  {'label': 'positive', 'score': 0.98436039686203},
#  {'label': 'positive', 'score': 0.9875465035438538},
#  {'label': 'positive', 'score': 0.9866361021995544},
#  {'label': 'positive', 'score': 0.9873142838478088},
#  {'label': 'positive', 'score': 0.9840509295463562},
#  {'label': 'positive', 'score': 0.9863119721412659},
#  {'label': 'positive', 'score': 0.9703145623207092},
#  {'label': 'positive', 'score': 0.9868319034576416},
#  {'label': 'positive', 'score': 0.9869837760925293},
#  {'label': 'positive', 'score': 0.9877671003341675},
#  {'label': 'positive', 'score': 0.98692387342453},
#  {'label': 'positive', 'score': 0.9835702180862427},
#  {'label': 'positive', 'score': 0.9859189987182617},
#  {'label': 'positive', 'score': 0.9866856336593628},
#  {'label': 'positive', 'score': 0.9864408373832703},
#  {'label': 'positive', 'score': 0.9735572338104248},
#  {'label': 'positive', 'score': 0.9880318641662598},
#  {'label': 'positive', 'score': 0.9866004586219788},
#  {'label': 'positive', 'score': 0.9872411489486694},
#  {'label': 'positive', 'score': 0.9833954572677612},
#  {'label': 'positive', 'score': 0.9879774451255798},
#  {'label': 'positive', 'score': 0.9866742491722107},
#  {'label': 'positive', 'score': 0.9870508909225464},
#  {'label': 'positive', 'score': 0.9878194332122803},
#  {'label': 'positive', 'score': 0.9570443034172058},
#  {'label': 'positive', 'score': 0.9881239533424377},
#  {'label': 'positive', 'score': 0.9862881898880005},
#  {'label': 'positive', 'score': 0.9870441555976868},
#  {'label': 'positive', 'score': 0.9873294830322266},
#  {'label': 'positive', 'score': 0.9810754060745239},
#  {'label': 'positive', 'score': 0.9864193797111511},
#  {'label': 'positive', 'score': 0.9809294939041138},
#  {'label': 'positive', 'score': 0.9868931770324707},
#  {'label': 'positive', 'score': 0.9890473484992981},
#  {'label': 'positive', 'score': 0.9866288900375366},
#  {'label': 'positive', 'score': 0.9866260886192322},
#  {'label': 'positive', 'score': 0.9251176714897156},
#  {'label': 'positive', 'score': 0.9460241198539734},
#  {'label': 'positive', 'score': 0.9856389164924622},
#  {'label': 'positive', 'score': 0.9873006939888},
#  {'label': 'positive', 'score': 0.9866361021995544},
#  {'label': 'positive', 'score': 0.974736750125885},
#  {'label': 'positive', 'score': 0.9858959317207336},
#  {'label': 'positive', 'score': 0.9874710440635681},
#  {'label': 'positive', 'score': 0.9876744151115417},
#  {'label': 'positive', 'score': 0.982740044593811},
#  {'label': 'positive', 'score': 0.971086323261261},
#  {'label': 'positive', 'score': 0.980107843875885},
#  {'label': 'positive', 'score': 0.9808002710342407},
#  {'label': 'positive', 'score': 0.9809494614601135},
#  {'label': 'positive', 'score': 0.9853606820106506},
#  {'label': 'positive', 'score': 0.9739660620689392},
#  {'label': 'neutral', 'score': 0.9899672269821167},
#  {'label': 'negative', 'score': 0.9554986357688904},
#  {'label': 'neutral', 'score': 0.9723196625709534},
#  {'label': 'neutral', 'score': 0.9244726896286011},
#  {'label': 'neutral', 'score': 0.9785923361778259},
#  {'label': 'positive', 'score': 0.961286723613739},
#  {'label': 'neutral', 'score': 0.9858194589614868},
#  {'label': 'positive', 'score': 0.9541624784469604},
#  {'label': 'positive', 'score': 0.9642959237098694},
#  {'label': 'neutral', 'score': 0.9515697956085205},
#  {'label': 'positive', 'score': 0.9823814034461975},
#  {'label': 'neutral', 'score': 0.9725845456123352},
#  {'label': 'positive', 'score': 0.9473999738693237},
#  {'label': 'neutral', 'score': 0.9768114686012268},
#  {'label': 'neutral', 'score': 0.9919643402099609},
#  {'label': 'neutral', 'score': 0.9829422235488892},
#  {'label': 'positive', 'score': 0.6726487874984741},
#  {'label': 'positive', 'score': 0.9857730269432068},
#  {'label': 'neutral', 'score': 0.9485540390014648},
#  {'label': 'positive', 'score': 0.9740294814109802},
#  {'label': 'positive', 'score': 0.6350584030151367},
#  {'label': 'positive', 'score': 0.6350584030151367},
#  {'label': 'neutral', 'score': 0.9948792457580566},
#  {'label': 'neutral', 'score': 0.9787458181381226},
#  {'label': 'neutral', 'score': 0.9944241642951965},
#  {'label': 'positive', 'score': 0.979288637638092},
#  {'label': 'positive', 'score': 0.9835156798362732},
#  {'label': 'neutral', 'score': 0.9925448298454285},
#  {'label': 'positive', 'score': 0.9864778518676758},
#  {'label': 'positive', 'score': 0.986591637134552},
#  {'label': 'positive', 'score': 0.9861055016517639},
#  {'label': 'positive', 'score': 0.9878578186035156},
#  {'label': 'positive', 'score': 0.9732881188392639},
#  {'label': 'positive', 'score': 0.8877556324005127},
#  {'label': 'positive', 'score': 0.9822067022323608},
#  {'label': 'positive', 'score': 0.9867261648178101},
#  {'label': 'positive', 'score': 0.9867919683456421},
#  {'label': 'positive', 'score': 0.9862563014030457},
#  {'label': 'positive', 'score': 0.9859387278556824},
#  {'label': 'positive', 'score': 0.9858435988426208},
#  {'label': 'positive', 'score': 0.9882110953330994},
#  {'label': 'positive', 'score': 0.9808927774429321},
#  {'label': 'positive', 'score': 0.987517774105072},
#  {'label': 'positive', 'score': 0.9857903718948364},
#  {'label': 'positive', 'score': 0.9875128865242004},
#  {'label': 'positive', 'score': 0.957880437374115},
#  {'label': 'positive', 'score': 0.9844055771827698},
#  {'label': 'positive', 'score': 0.9865230917930603},
#  {'label': 'positive', 'score': 0.9867392778396606},
#  {'label': 'positive', 'score': 0.9867947697639465},
#  {'label': 'positive', 'score': 0.9863406419754028},
#  {'label': 'positive', 'score': 0.9864931702613831},
#  {'label': 'neutral', 'score': 0.9940569400787354},
#  {'label': 'positive', 'score': 0.9861264824867249},
#  {'label': 'positive', 'score': 0.9836438298225403},
#  {'label': 'positive', 'score': 0.9873851537704468},
#  {'label': 'positive', 'score': 0.9867174625396729},
#  {'label': 'positive', 'score': 0.9887682795524597},
#  {'label': 'positive', 'score': 0.9865639209747314},
#  {'label': 'positive', 'score': 0.9878943562507629},
#  {'label': 'positive', 'score': 0.986459493637085},
#  {'label': 'positive', 'score': 0.9870620369911194},
#  {'label': 'positive', 'score': 0.9873036742210388},
#  {'label': 'positive', 'score': 0.987234890460968},
#  {'label': 'positive', 'score': 0.9875494241714478},
#  {'label': 'positive', 'score': 0.9792223572731018},
#  {'label': 'positive', 'score': 0.9883350133895874},
#  {'label': 'positive', 'score': 0.982883870601654},
#  {'label': 'positive', 'score': 0.9793807864189148},
#  {'label': 'positive', 'score': 0.9732317924499512},
#  {'label': 'positive', 'score': 0.9866689443588257},
#  {'label': 'positive', 'score': 0.980937659740448},
#  {'label': 'positive', 'score': 0.9825582504272461},
#  {'label': 'positive', 'score': 0.9893374443054199},
#  {'label': 'positive', 'score': 0.9855265617370605},
#  {'label': 'positive', 'score': 0.9875386953353882},
#  {'label': 'positive', 'score': 0.9877099990844727},
#  {'label': 'positive', 'score': 0.9258127808570862},
#  {'label': 'positive', 'score': 0.9675298929214478},
#  {'label': 'positive', 'score': 0.9737087488174438},
#  {'label': 'positive', 'score': 0.9837390184402466},
#  {'label': 'neutral', 'score': 0.9695934057235718},
#  {'label': 'positive', 'score': 0.9877294898033142},
#  {'label': 'positive', 'score': 0.9818239808082581},
#  {'label': 'positive', 'score': 0.9859117865562439},
#  {'label': 'positive', 'score': 0.9863619804382324},
#  {'label': 'positive', 'score': 0.9832248687744141},
#  {'label': 'positive', 'score': 0.9848613739013672},
#  {'label': 'positive', 'score': 0.977571427822113},
#  {'label': 'positive', 'score': 0.9856997132301331},
#  {'label': 'positive', 'score': 0.9764617085456848},
#  {'label': 'positive', 'score': 0.9683294296264648},
#  {'label': 'positive', 'score': 0.983199954032898},
#  {'label': 'positive', 'score': 0.9853280186653137},
#  {'label': 'positive', 'score': 0.9866058230400085},
#  {'label': 'positive', 'score': 0.9356358647346497},
#  {'label': 'positive', 'score': 0.9743959903717041},
#  {'label': 'positive', 'score': 0.9870645999908447},
#  {'label': 'positive', 'score': 0.9869725108146667},
#  {'label': 'positive', 'score': 0.9873864054679871},
#  {'label': 'positive', 'score': 0.9883429408073425},
#  {'label': 'neutral', 'score': 0.9941864013671875},
#  {'label': 'positive', 'score': 0.977336585521698},
#  {'label': 'positive', 'score': 0.987542986869812},
#  {'label': 'positive', 'score': 0.9873883128166199},
#  {'label': 'positive', 'score': 0.987386167049408},
#  {'label': 'positive', 'score': 0.9873628616333008},
#  {'label': 'positive', 'score': 0.9879563450813293},
#  {'label': 'positive', 'score': 0.9878498911857605},
#  {'label': 'positive', 'score': 0.9877297282218933},
#  {'label': 'positive', 'score': 0.987631618976593},
#  {'label': 'positive', 'score': 0.9876551032066345},
#  {'label': 'positive', 'score': 0.9877952337265015},
#  {'label': 'positive', 'score': 0.9876595139503479},
#  {'label': 'positive', 'score': 0.9877597689628601},
#  {'label': 'positive', 'score': 0.9873133301734924},
#  {'label': 'positive', 'score': 0.987627387046814},
#  {'label': 'positive', 'score': 0.9872546792030334},
#  {'label': 'positive', 'score': 0.9875983595848083},
#  {'label': 'positive', 'score': 0.9874304533004761},
#  {'label': 'positive', 'score': 0.9871964454650879},
#  {'label': 'positive', 'score': 0.9871182441711426},
#  {'label': 'positive', 'score': 0.983680248260498},
#  {'label': 'positive', 'score': 0.9842824339866638},
#  {'label': 'positive', 'score': 0.9848047494888306},
#  {'label': 'positive', 'score': 0.9847995042800903},
#  {'label': 'positive', 'score': 0.9834096431732178},
#  {'label': 'positive', 'score': 0.9878174662590027},
#  {'label': 'neutral', 'score': 0.9922530055046082},
#  {'label': 'positive', 'score': 0.9877066016197205},
#  {'label': 'positive', 'score': 0.986130952835083},
#  {'label': 'positive', 'score': 0.9875853061676025},
#  {'label': 'positive', 'score': 0.9844020009040833},
#  {'label': 'positive', 'score': 0.9771888256072998},
#  {'label': 'positive', 'score': 0.9853304624557495},
#  {'label': 'positive', 'score': 0.9859435558319092},
#  {'label': 'positive', 'score': 0.9852917194366455},
#  {'label': 'positive', 'score': 0.9827753901481628},
#  {'label': 'positive', 'score': 0.9863452315330505},
#  {'label': 'positive', 'score': 0.9860308170318604},
#  {'label': 'positive', 'score': 0.9847466945648193},
#  {'label': 'positive', 'score': 0.9859880805015564},
#  {'label': 'positive', 'score': 0.9865149855613708},
#  {'label': 'positive', 'score': 0.9856992363929749},
#  {'label': 'positive', 'score': 0.9865342378616333},
#  {'label': 'positive', 'score': 0.9811297059059143},
#  {'label': 'positive', 'score': 0.9851521253585815},
#  {'label': 'positive', 'score': 0.9856654405593872},
#  {'label': 'positive', 'score': 0.9833009243011475},
#  {'label': 'positive', 'score': 0.9874290823936462},
#  {'label': 'positive', 'score': 0.9846663475036621},
#  {'label': 'positive', 'score': 0.9857931733131409},
#  {'label': 'neutral', 'score': 0.9922622442245483},
#  {'label': 'positive', 'score': 0.9829828143119812},
#  {'label': 'positive', 'score': 0.9856589436531067},
#  {'label': 'positive', 'score': 0.9824941754341125},
#  {'label': 'positive', 'score': 0.9710521697998047},
#  {'label': 'positive', 'score': 0.9875500798225403},
#  {'label': 'positive', 'score': 0.9883489608764648},
#  {'label': 'positive', 'score': 0.9858308434486389},
#  {'label': 'positive', 'score': 0.9854782819747925},
#  {'label': 'positive', 'score': 0.9882142543792725},
#  {'label': 'positive', 'score': 0.9881888628005981},
#  {'label': 'neutral', 'score': 0.8373351097106934},
#  {'label': 'positive', 'score': 0.9846469163894653},
#  {'label': 'positive', 'score': 0.9799932837486267},
#  {'label': 'positive', 'score': 0.9869561195373535},
#  {'label': 'positive', 'score': 0.9873422384262085},
#  {'label': 'positive', 'score': 0.9882767796516418},
#  {'label': 'positive', 'score': 0.9849373698234558},
#  {'label': 'positive', 'score': 0.9846282005310059},
#  {'label': 'positive', 'score': 0.984516441822052},
#  {'label': 'positive', 'score': 0.9854304790496826},
#  {'label': 'positive', 'score': 0.9848237037658691},
#  {'label': 'positive', 'score': 0.984253466129303},
#  {'label': 'neutral', 'score': 0.9928551316261292},
#  {'label': 'positive', 'score': 0.9792096614837646},
#  {'label': 'positive', 'score': 0.986185610294342},
#  {'label': 'positive', 'score': 0.9875755310058594},
#  {'label': 'positive', 'score': 0.9872981309890747},
#  {'label': 'positive', 'score': 0.9860219955444336},
#  {'label': 'positive', 'score': 0.9875024557113647},
#  {'label': 'positive', 'score': 0.9864543080329895},
#  {'label': 'positive', 'score': 0.9860513210296631},
#  {'label': 'positive', 'score': 0.9869389533996582},
#  {'label': 'positive', 'score': 0.9864441752433777},
#  {'label': 'positive', 'score': 0.9865753054618835},
#  {'label': 'positive', 'score': 0.9864081144332886},
#  {'label': 'positive', 'score': 0.9864864349365234},
#  {'label': 'positive', 'score': 0.9863399267196655},
#  {'label': 'positive', 'score': 0.9867732524871826},
#  {'label': 'positive', 'score': 0.9867545962333679},
#  {'label': 'positive', 'score': 0.9870347380638123},
#  {'label': 'positive', 'score': 0.9871551990509033},
#  {'label': 'positive', 'score': 0.9866503477096558},
#  {'label': 'positive', 'score': 0.9869220852851868},
#  {'label': 'positive', 'score': 0.9861404895782471},
#  {'label': 'positive', 'score': 0.9861333966255188},
#  {'label': 'positive', 'score': 0.9871087670326233},
#  {'label': 'positive', 'score': 0.98746258020401},
#  {'label': 'positive', 'score': 0.9866754412651062},
#  {'label': 'positive', 'score': 0.9874415397644043},
#  {'label': 'positive', 'score': 0.9880104660987854},
#  {'label': 'positive', 'score': 0.9877759218215942},
#  {'label': 'positive', 'score': 0.9871556758880615},
#  {'label': 'positive', 'score': 0.986872673034668},
#  {'label': 'positive', 'score': 0.9816519021987915},
#  {'label': 'positive', 'score': 0.9862008690834045},
#  {'label': 'positive', 'score': 0.9867541193962097},
#  {'label': 'positive', 'score': 0.9866313338279724},
#  {'label': 'positive', 'score': 0.9867941737174988},
#  {'label': 'positive', 'score': 0.9845144152641296},
#  {'label': 'positive', 'score': 0.9832133054733276},
#  {'label': 'positive', 'score': 0.9867761731147766},
#  {'label': 'positive', 'score': 0.9869656562805176},
#  {'label': 'positive', 'score': 0.9869323372840881},
#  {'label': 'positive', 'score': 0.9884827733039856},
#  {'label': 'positive', 'score': 0.9881809949874878},
#  {'label': 'positive', 'score': 0.9850596189498901},
#  {'label': 'positive', 'score': 0.9828277826309204},
#  {'label': 'positive', 'score': 0.9860360622406006},
#  {'label': 'positive', 'score': 0.9842632412910461},
#  {'label': 'positive', 'score': 0.984946608543396},
#  {'label': 'positive', 'score': 0.9869934320449829},
#  {'label': 'positive', 'score': 0.9869188666343689},
#  {'label': 'positive', 'score': 0.9862856268882751},
#  {'label': 'positive', 'score': 0.9857978224754333},
#  {'label': 'positive', 'score': 0.982874870300293},
#  {'label': 'positive', 'score': 0.9789360761642456},
#  {'label': 'positive', 'score': 0.987392246723175},
#  {'label': 'positive', 'score': 0.9871302247047424},
#  {'label': 'positive', 'score': 0.9857943058013916},
#  {'label': 'positive', 'score': 0.9648094177246094},
#  {'label': 'positive', 'score': 0.9865943193435669},
#  {'label': 'positive', 'score': 0.9737640023231506},
#  {'label': 'positive', 'score': 0.9863611459732056},
#  {'label': 'positive', 'score': 0.9855473041534424},
#  {'label': 'neutral', 'score': 0.991675853729248},
#  {'label': 'positive', 'score': 0.9774501323699951},
#  {'label': 'positive', 'score': 0.9874807000160217},
#  {'label': 'positive', 'score': 0.9461331963539124},
#  {'label': 'positive', 'score': 0.9865597486495972},
#  {'label': 'positive', 'score': 0.983871340751648},
#  {'label': 'positive', 'score': 0.9841348528862},
#  {'label': 'positive', 'score': 0.9549572467803955},
#  {'label': 'positive', 'score': 0.9876214861869812},
#  {'label': 'positive', 'score': 0.9847891330718994},
#  {'label': 'positive', 'score': 0.9813474416732788},
#  {'label': 'positive', 'score': 0.9694115519523621},
#  {'label': 'positive', 'score': 0.9880353808403015},
#  {'label': 'positive', 'score': 0.9852927327156067},
#  {'label': 'neutral', 'score': 0.9806120991706848},
#  {'label': 'positive', 'score': 0.9836229681968689},
#  {'label': 'positive', 'score': 0.9793826341629028},
#  {'label': 'positive', 'score': 0.9812867045402527},
#  {'label': 'positive', 'score': 0.9814202189445496},
#  {'label': 'positive', 'score': 0.9214516282081604},
#  {'label': 'positive', 'score': 0.9888299107551575},
#  {'label': 'positive', 'score': 0.986549973487854},
#  {'label': 'positive', 'score': 0.9871683120727539},
#  {'label': 'positive', 'score': 0.9778861999511719},
#  {'label': 'neutral', 'score': 0.9715084433555603},
#  {'label': 'positive', 'score': 0.9802104830741882},
#  {'label': 'positive', 'score': 0.9854780435562134},
#  {'label': 'positive', 'score': 0.9858843684196472},
#  {'label': 'positive', 'score': 0.986812174320221},
#  {'label': 'positive', 'score': 0.9723671078681946},
#  {'label': 'positive', 'score': 0.987594723701477},
#  {'label': 'positive', 'score': 0.9861130118370056},
#  {'label': 'positive', 'score': 0.9697579741477966},
#  {'label': 'positive', 'score': 0.9858115911483765},
#  {'label': 'positive', 'score': 0.9829505085945129},
#  {'label': 'positive', 'score': 0.9858385920524597},
#  {'label': 'positive', 'score': 0.9855631589889526},
#  {'label': 'positive', 'score': 0.9843255281448364},
#  {'label': 'positive', 'score': 0.9861148595809937},
#  {'label': 'positive', 'score': 0.986477255821228},
#  {'label': 'positive', 'score': 0.9798299074172974},
#  {'label': 'positive', 'score': 0.9778065085411072},
#  {'label': 'positive', 'score': 0.9427984952926636},
#  {'label': 'positive', 'score': 0.9762979745864868},
#  {'label': 'positive', 'score': 0.9843758940696716},
#  {'label': 'positive', 'score': 0.9844805598258972},
#  {'label': 'positive', 'score': 0.9874897599220276},
#  {'label': 'positive', 'score': 0.9874306917190552},
#  {'label': 'positive', 'score': 0.9849864840507507},
#  {'label': 'positive', 'score': 0.98493492603302},
#  {'label': 'positive', 'score': 0.9756220579147339},
#  {'label': 'positive', 'score': 0.9861753582954407},
#  {'label': 'positive', 'score': 0.9869483709335327},
#  {'label': 'positive', 'score': 0.9875333309173584},
#  {'label': 'positive', 'score': 0.9864856004714966},
#  {'label': 'positive', 'score': 0.982952356338501},
#  {'label': 'positive', 'score': 0.9846049547195435},
#  {'label': 'positive', 'score': 0.9860286116600037},
#  {'label': 'positive', 'score': 0.9828786849975586},
#  {'label': 'neutral', 'score': 0.8177017569541931},
#  {'label': 'positive', 'score': 0.9858266711235046},
#  {'label': 'positive', 'score': 0.987571120262146},
#  {'label': 'positive', 'score': 0.9870295524597168},
#  {'label': 'positive', 'score': 0.9870246648788452},
#  {'label': 'positive', 'score': 0.9775811433792114},
#  {'label': 'positive', 'score': 0.9867549538612366},
#  {'label': 'positive', 'score': 0.9858958125114441},
#  {'label': 'positive', 'score': 0.986032247543335},
#  {'label': 'positive', 'score': 0.9853695631027222},
#  {'label': 'positive', 'score': 0.9875141978263855},
#  {'label': 'positive', 'score': 0.9877740740776062},
#  {'label': 'positive', 'score': 0.97450190782547},
#  {'label': 'positive', 'score': 0.9857306480407715},
#  {'label': 'positive', 'score': 0.9798132181167603},
#  {'label': 'positive', 'score': 0.9871838092803955},
#  {'label': 'positive', 'score': 0.987441897392273},
#  {'label': 'positive', 'score': 0.976384699344635},
#  {'label': 'positive', 'score': 0.9826804995536804},
#  {'label': 'positive', 'score': 0.986409604549408},
#  {'label': 'positive', 'score': 0.9876101016998291},
#  {'label': 'positive', 'score': 0.9871476292610168},
#  {'label': 'positive', 'score': 0.9841400384902954},
#  {'label': 'positive', 'score': 0.9863150119781494},
#  {'label': 'positive', 'score': 0.986801266670227},
#  {'label': 'positive', 'score': 0.9835610389709473},
#  {'label': 'positive', 'score': 0.9881072044372559},
#  {'label': 'positive', 'score': 0.9835759997367859},
#  {'label': 'positive', 'score': 0.9832163453102112},
#  {'label': 'positive', 'score': 0.9844287633895874},
#  {'label': 'positive', 'score': 0.9853508472442627},
#  {'label': 'positive', 'score': 0.9863898158073425},
#  {'label': 'positive', 'score': 0.9839280247688293},
#  {'label': 'positive', 'score': 0.9871792793273926},
#  {'label': 'positive', 'score': 0.9850807785987854},
#  {'label': 'positive', 'score': 0.9737961292266846},
#  {'label': 'positive', 'score': 0.9619926810264587},
#  {'label': 'positive', 'score': 0.9819779992103577},
#  {'label': 'positive', 'score': 0.5199377536773682},
#  {'label': 'neutral', 'score': 0.9933753609657288},
#  {'label': 'neutral', 'score': 0.8969889283180237},
#  {'label': 'neutral', 'score': 0.9273781180381775},
#  {'label': 'neutral', 'score': 0.9873456358909607},
#  {'label': 'positive', 'score': 0.7180153727531433},
#  {'label': 'positive', 'score': 0.9846611618995667},
#  {'label': 'positive', 'score': 0.6620875597000122},
#  {'label': 'positive', 'score': 0.6659059524536133},
#  {'label': 'neutral', 'score': 0.9049929976463318},
#  {'label': 'positive', 'score': 0.9594939351081848},
#  {'label': 'neutral', 'score': 0.6103329062461853},
#  {'label': 'positive', 'score': 0.9676944017410278},
#  {'label': 'neutral', 'score': 0.9941957592964172},
#  {'label': 'neutral', 'score': 0.979347288608551},
#  {'label': 'neutral', 'score': 0.9293912053108215},
#  {'label': 'positive', 'score': 0.9830185174942017},
#  {'label': 'positive', 'score': 0.9811914563179016},
#  {'label': 'neutral', 'score': 0.9941442608833313},
#  {'label': 'neutral', 'score': 0.9932851791381836},
#  {'label': 'positive', 'score': 0.9764366149902344},
#  {'label': 'neutral', 'score': 0.9940813183784485},
#  {'label': 'neutral', 'score': 0.9929800629615784},
#  {'label': 'neutral', 'score': 0.9876341819763184},
#  {'label': 'neutral', 'score': 0.9892055988311768},
#  {'label': 'neutral', 'score': 0.9910070300102234},
#  {'label': 'neutral', 'score': 0.9830721616744995},
#  {'label': 'neutral', 'score': 0.8204039931297302},
#  {'label': 'neutral', 'score': 0.987737774848938},
#  {'label': 'negative', 'score': 0.7485790848731995},
#  {'label': 'negative', 'score': 0.7172774076461792},
#  {'label': 'negative', 'score': 0.7653279304504395},
#  {'label': 'neutral', 'score': 0.9760965704917908},
#  {'label': 'positive', 'score': 0.9768532514572144},
#  {'label': 'positive', 'score': 0.7870859503746033},
#  {'label': 'neutral', 'score': 0.9927127957344055},
#  {'label': 'positive', 'score': 0.9768120646476746},
#  {'label': 'positive', 'score': 0.9764965176582336},
#  {'label': 'neutral', 'score': 0.99425208568573},
#  {'label': 'neutral', 'score': 0.9942268133163452},
#  {'label': 'neutral', 'score': 0.9886675477027893},
#  {'label': 'positive', 'score': 0.9214022159576416},
#  {'label': 'neutral', 'score': 0.9918962121009827},
#  {'label': 'positive', 'score': 0.9688994884490967},
#  {'label': 'neutral', 'score': 0.9935769438743591},
#  {'label': 'neutral', 'score': 0.9917780160903931},
#  {'label': 'positive', 'score': 0.9690463542938232},
#  {'label': 'positive', 'score': 0.9722416400909424},
#  {'label': 'neutral', 'score': 0.9853371977806091},
#  {'label': 'positive', 'score': 0.9774739146232605},
#  {'label': 'positive', 'score': 0.9399055242538452},
#  {'label': 'neutral', 'score': 0.9941211342811584},
#  {'label': 'neutral', 'score': 0.9648109674453735},
#  {'label': 'neutral', 'score': 0.9920763969421387},
#  {'label': 'positive', 'score': 0.9845883250236511},
#  {'label': 'neutral', 'score': 0.9844675660133362},
#  {'label': 'neutral', 'score': 0.9818313717842102},
#  {'label': 'neutral', 'score': 0.8940318822860718},
#  {'label': 'positive', 'score': 0.9727869033813477},
#  {'label': 'positive', 'score': 0.9716646075248718},
#  {'label': 'neutral', 'score': 0.9425672292709351},
#  {'label': 'neutral', 'score': 0.9928818941116333},
#  {'label': 'neutral', 'score': 0.9937187433242798},
#  {'label': 'positive', 'score': 0.9785436987876892},
#  {'label': 'neutral', 'score': 0.9795565605163574},
#  {'label': 'positive', 'score': 0.9835116863250732},
#  {'label': 'positive', 'score': 0.9842752814292908},
#  {'label': 'neutral', 'score': 0.8825790882110596},
#  {'label': 'neutral', 'score': 0.9724297523498535},
#  {'label': 'positive', 'score': 0.9800946712493896},
#  {'label': 'positive', 'score': 0.9718888401985168},
#  {'label': 'positive', 'score': 0.981117308139801},
#  {'label': 'neutral', 'score': 0.9938837885856628},
#  {'label': 'neutral', 'score': 0.9838558435440063},
#  {'label': 'positive', 'score': 0.9356921911239624},
#  {'label': 'positive', 'score': 0.9598091244697571},
#  {'label': 'neutral', 'score': 0.9931121468544006},
#  {'label': 'positive', 'score': 0.9812120199203491},
#  {'label': 'neutral', 'score': 0.9859338402748108},
#  {'label': 'neutral', 'score': 0.9824513792991638},
#  {'label': 'neutral', 'score': 0.9669452905654907},
#  {'label': 'positive', 'score': 0.9520521759986877},
#  {'label': 'neutral', 'score': 0.9935564398765564},
#  {'label': 'neutral', 'score': 0.9844509363174438},
#  {'label': 'neutral', 'score': 0.986458957195282},
#  {'label': 'positive', 'score': 0.986706554889679},
#  {'label': 'neutral', 'score': 0.879509687423706},
#  {'label': 'neutral', 'score': 0.9818053841590881},
#  {'label': 'neutral', 'score': 0.993821382522583},
#  {'label': 'neutral', 'score': 0.7737467885017395},
#  {'label': 'neutral', 'score': 0.9885263442993164},
#  {'label': 'neutral', 'score': 0.9894696474075317},
#  {'label': 'positive', 'score': 0.3998560607433319},
#  {'label': 'positive', 'score': 0.946300745010376},
#  {'label': 'positive', 'score': 0.9862791299819946},
#  {'label': 'positive', 'score': 0.9769046306610107},
#  {'label': 'neutral', 'score': 0.9899995923042297},
#  {'label': 'positive', 'score': 0.975184440612793},
#  {'label': 'neutral', 'score': 0.9907413721084595},
#  {'label': 'neutral', 'score': 0.9750345945358276},
#  {'label': 'positive', 'score': 0.9804774522781372},
#  {'label': 'neutral', 'score': 0.9938774704933167},
#  {'label': 'neutral', 'score': 0.9806749224662781},
#  {'label': 'positive', 'score': 0.9674515724182129},
#  {'label': 'neutral', 'score': 0.9636968374252319},
#  {'label': 'positive', 'score': 0.9684840440750122},
#  {'label': 'positive', 'score': 0.9798882603645325},
#  {'label': 'neutral', 'score': 0.9939385652542114},
#  {'label': 'negative', 'score': 0.965295135974884},
#  {'label': 'neutral', 'score': 0.993251621723175},
#  {'label': 'neutral', 'score': 0.9936188459396362},
#  {'label': 'neutral', 'score': 0.9544255137443542},
#  {'label': 'neutral', 'score': 0.9726214408874512},
#  {'label': 'positive', 'score': 0.9717556834220886},
#  {'label': 'positive', 'score': 0.9541372656822205},
#  {'label': 'neutral', 'score': 0.9593335390090942},
#  {'label': 'neutral', 'score': 0.9919005632400513},
#  {'label': 'neutral', 'score': 0.9943177103996277},
#  {'label': 'positive', 'score': 0.9118621349334717},
#  {'label': 'neutral', 'score': 0.95786052942276},
#  {'label': 'neutral', 'score': 0.9935209155082703},
#  {'label': 'neutral', 'score': 0.9877496361732483},
#  {'label': 'neutral', 'score': 0.8904370665550232},
#  {'label': 'neutral', 'score': 0.9607275724411011},
#  {'label': 'neutral', 'score': 0.9925161004066467},
#  {'label': 'neutral', 'score': 0.7484886050224304},
#  {'label': 'positive', 'score': 0.9859241247177124},
#  {'label': 'positive', 'score': 0.9589160084724426},
#  {'label': 'positive', 'score': 0.9874852299690247},
#  {'label': 'neutral', 'score': 0.9947329759597778},
#  {'label': 'neutral', 'score': 0.9830471873283386},
#  {'label': 'neutral', 'score': 0.9863117337226868},
#  {'label': 'neutral', 'score': 0.9910383224487305},
#  {'label': 'neutral', 'score': 0.9703150987625122},
#  {'label': 'positive', 'score': 0.9848875999450684},
#  {'label': 'positive', 'score': 0.9839702248573303},
#  {'label': 'positive', 'score': 0.9868398904800415},
#  {'label': 'neutral', 'score': 0.9939284324645996},
#  {'label': 'neutral', 'score': 0.9935071468353271},
#  {'label': 'neutral', 'score': 0.9303587079048157},
#  {'label': 'positive', 'score': 0.9751289486885071},
#  {'label': 'neutral', 'score': 0.974299967288971},
#  {'label': 'neutral', 'score': 0.9472682476043701},
#  {'label': 'positive', 'score': 0.9819905161857605},
#  {'label': 'neutral', 'score': 0.9753215312957764},
#  {'label': 'neutral', 'score': 0.9948200583457947},
#  {'label': 'positive', 'score': 0.9865583777427673},
#  {'label': 'negative', 'score': 0.9849610328674316},
#  {'label': 'neutral', 'score': 0.9871470928192139},
#  {'label': 'positive', 'score': 0.9869551062583923},
#  {'label': 'negative', 'score': 0.9787281155586243},
#  {'label': 'negative', 'score': 0.9874666333198547},
#  {'label': 'negative', 'score': 0.9735807180404663},
#  {'label': 'positive', 'score': 0.9700654745101929},
#  {'label': 'positive', 'score': 0.9413811564445496},
#  {'label': 'positive', 'score': 0.9816393852233887},
#  {'label': 'positive', 'score': 0.9850577712059021},
#  {'label': 'positive', 'score': 0.9868770837783813},
#  {'label': 'positive', 'score': 0.9867556095123291},
#  {'label': 'positive', 'score': 0.9771832227706909},
#  {'label': 'positive', 'score': 0.9839787483215332},
#  {'label': 'positive', 'score': 0.9673740267753601},
#  {'label': 'positive', 'score': 0.9794867038726807},
#  {'label': 'positive', 'score': 0.9841045141220093},
#  {'label': 'positive', 'score': 0.980005145072937},
#  {'label': 'positive', 'score': 0.9860358238220215},
#  {'label': 'positive', 'score': 0.9824579358100891},
#  {'label': 'positive', 'score': 0.9866355061531067},
#  {'label': 'positive', 'score': 0.9795000553131104},
#  {'label': 'positive', 'score': 0.986782431602478},
#  {'label': 'positive', 'score': 0.9793834090232849},
#  {'label': 'positive', 'score': 0.9792567491531372},
#  {'label': 'positive', 'score': 0.9863495230674744},
#  {'label': 'positive', 'score': 0.9859506487846375},
#  {'label': 'positive', 'score': 0.9863337874412537},
#  {'label': 'neutral', 'score': 0.9446206092834473},
#  {'label': 'positive', 'score': 0.9712597131729126},
#  {'label': 'neutral', 'score': 0.9804968237876892},
#  {'label': 'neutral', 'score': 0.9905146360397339},
#  {'label': 'neutral', 'score': 0.9871067404747009},
#  {'label': 'neutral', 'score': 0.9272560477256775},
#  {'label': 'neutral', 'score': 0.9869088530540466},
#  {'label': 'neutral', 'score': 0.9944774508476257},
#  {'label': 'positive', 'score': 0.9540179967880249},
#  {'label': 'neutral', 'score': 0.965919017791748},
#  {'label': 'positive', 'score': 0.983651340007782},
#  {'label': 'neutral', 'score': 0.9939684867858887},
#  {'label': 'neutral', 'score': 0.9892102479934692},
#  {'label': 'positive', 'score': 0.9876048564910889},
#  {'label': 'positive', 'score': 0.9791021943092346},
#  {'label': 'neutral', 'score': 0.9835440516471863},
#  {'label': 'positive', 'score': 0.9873297214508057},
#  {'label': 'positive', 'score': 0.9775007963180542},
#  {'label': 'positive', 'score': 0.9799091219902039},
#  {'label': 'positive', 'score': 0.987403154373169},
#  {'label': 'positive', 'score': 0.9824474453926086},
#  {'label': 'positive', 'score': 0.986239492893219},
#  {'label': 'positive', 'score': 0.9827845692634583},
#  {'label': 'positive', 'score': 0.9841880798339844},
#  {'label': 'positive', 'score': 0.9816862344741821},
#  {'label': 'positive', 'score': 0.9824804663658142},
#  {'label': 'neutral', 'score': 0.8843246102333069},
#  {'label': 'positive', 'score': 0.984859049320221},
#  {'label': 'positive', 'score': 0.986465334892273},
#  {'label': 'positive', 'score': 0.9871155023574829},
#  {'label': 'positive', 'score': 0.985749363899231},
#  {'label': 'positive', 'score': 0.9854793548583984},
#  {'label': 'positive', 'score': 0.983194887638092},
#  {'label': 'positive', 'score': 0.9860090613365173},
#  {'label': 'positive', 'score': 0.9783992171287537},
#  {'label': 'positive', 'score': 0.9816646575927734},
#  {'label': 'positive', 'score': 0.9848433136940002},
#  {'label': 'positive', 'score': 0.9698508977890015},
#  {'label': 'positive', 'score': 0.9829269051551819},
#  {'label': 'positive', 'score': 0.9833727478981018},
#  {'label': 'positive', 'score': 0.977025032043457},
#  {'label': 'positive', 'score': 0.9867340326309204},
#  {'label': 'positive', 'score': 0.9862869381904602},
#  {'label': 'positive', 'score': 0.9866934418678284},
#  {'label': 'positive', 'score': 0.9837942719459534},
#  {'label': 'positive', 'score': 0.9641151428222656},
#  {'label': 'positive', 'score': 0.9819138646125793},
#  {'label': 'positive', 'score': 0.9854463338851929},
#  {'label': 'neutral', 'score': 0.98543381690979},
#  {'label': 'neutral', 'score': 0.9875702261924744},
#  {'label': 'positive', 'score': 0.9859397411346436},
#  {'label': 'positive', 'score': 0.9780354499816895},
#  {'label': 'neutral', 'score': 0.9927768707275391},
#  {'label': 'positive', 'score': 0.9855470657348633},
#  {'label': 'positive', 'score': 0.738466739654541},
#  {'label': 'neutral', 'score': 0.9903249740600586},
#  {'label': 'neutral', 'score': 0.9721437692642212},
#  {'label': 'neutral', 'score': 0.9209031462669373},
#  {'label': 'positive', 'score': 0.8044646978378296},
#  {'label': 'positive', 'score': 0.985301673412323},
#  {'label': 'neutral', 'score': 0.689751386642456},
#  {'label': 'neutral', 'score': 0.9878242015838623},
#  {'label': 'neutral', 'score': 0.9326319098472595},
#  {'label': 'positive', 'score': 0.9871680736541748},
#  {'label': 'positive', 'score': 0.9675083756446838},
#  {'label': 'positive', 'score': 0.9874246716499329},
#  {'label': 'neutral', 'score': 0.9906823635101318},
#  {'label': 'positive', 'score': 0.9775679111480713},
#  {'label': 'neutral', 'score': 0.9882673621177673},
#  {'label': 'positive', 'score': 0.9433693289756775},
#  {'label': 'neutral', 'score': 0.9938452839851379},
#  {'label': 'positive', 'score': 0.9875470995903015},
#  {'label': 'positive', 'score': 0.9825782179832458},
#  {'label': 'positive', 'score': 0.9720048308372498},
#  {'label': 'positive', 'score': 0.9622301459312439},
#  {'label': 'positive', 'score': 0.9570069313049316},
#  {'label': 'positive', 'score': 0.969813346862793},
#  {'label': 'positive', 'score': 0.9668393731117249},
#  {'label': 'positive', 'score': 0.9502745866775513},
#  {'label': 'positive', 'score': 0.8891413807868958},
#  {'label': 'positive', 'score': 0.9724283218383789},
#  {'label': 'positive', 'score': 0.9689590334892273},
#  {'label': 'positive', 'score': 0.9716800451278687},
#  {'label': 'positive', 'score': 0.9157946109771729},
#  {'label': 'positive', 'score': 0.9858961701393127},
#  {'label': 'positive', 'score': 0.9714150428771973},
#  {'label': 'positive', 'score': 0.9622218608856201},
#  {'label': 'positive', 'score': 0.9749578833580017},
#  {'label': 'positive', 'score': 0.9748769998550415},
#  {'label': 'positive', 'score': 0.954975962638855},
#  {'label': 'positive', 'score': 0.9744021892547607},
#  {'label': 'positive', 'score': 0.9732130765914917},
#  {'label': 'positive', 'score': 0.9776605367660522},
#  {'label': 'positive', 'score': 0.9489825367927551},
#  {'label': 'positive', 'score': 0.9776496887207031},
#  {'label': 'positive', 'score': 0.9820781350135803},
#  {'label': 'positive', 'score': 0.9851021766662598},
#  {'label': 'positive', 'score': 0.9874657988548279},
#  {'label': 'negative', 'score': 0.7795929908752441},
#  {'label': 'positive', 'score': 0.982093870639801},
#  {'label': 'neutral', 'score': 0.9877907037734985},
#  {'label': 'positive', 'score': 0.9797800183296204},
#  {'label': 'negative', 'score': 0.9882624745368958},
#  {'label': 'negative', 'score': 0.9835702180862427},
#  {'label': 'negative', 'score': 0.9843804836273193},
#  {'label': 'negative', 'score': 0.9814348220825195},
#  {'label': 'negative', 'score': 0.9868056774139404},
#  {'label': 'negative', 'score': 0.9805334806442261},
#  {'label': 'negative', 'score': 0.9858126640319824},
#  {'label': 'negative', 'score': 0.9841036796569824},
#  {'label': 'negative', 'score': 0.9888812899589539},
#  {'label': 'negative', 'score': 0.9855219125747681},
#  {'label': 'negative', 'score': 0.9863770604133606},
#  {'label': 'negative', 'score': 0.9892607927322388},
#  {'label': 'negative', 'score': 0.987106442451477},
#  {'label': 'negative', 'score': 0.9828345775604248},
#  {'label': 'negative', 'score': 0.988690972328186},
#  {'label': 'negative', 'score': 0.9874048829078674},
#  {'label': 'neutral', 'score': 0.9809101223945618},
#  {'label': 'positive', 'score': 0.9865707755088806},
#  {'label': 'positive', 'score': 0.9781861901283264},
#  {'label': 'positive', 'score': 0.9853374361991882},
#  {'label': 'positive', 'score': 0.986642599105835},
#  {'label': 'positive', 'score': 0.9862396121025085},
#  {'label': 'positive', 'score': 0.9864206314086914},
#  {'label': 'positive', 'score': 0.9874128103256226},
#  {'label': 'negative', 'score': 0.9704686999320984},
#  {'label': 'neutral', 'score': 0.9713970422744751},
#  {'label': 'neutral', 'score': 0.9843591451644897},
#  {'label': 'positive', 'score': 0.7078757286071777},
#  {'label': 'negative', 'score': 0.9819002151489258},
#  {'label': 'negative', 'score': 0.9068664312362671},
#  {'label': 'negative', 'score': 0.9804880619049072},
#  {'label': 'negative', 'score': 0.9526375532150269},
#  {'label': 'positive', 'score': 0.9869193434715271},
#  {'label': 'positive', 'score': 0.9851366281509399},
#  {'label': 'positive', 'score': 0.986223042011261},
#  {'label': 'positive', 'score': 0.9790521860122681},
#  {'label': 'positive', 'score': 0.9887357354164124},
#  {'label': 'positive', 'score': 0.9857318997383118},
#  {'label': 'neutral', 'score': 0.9653990268707275},
#  {'label': 'neutral', 'score': 0.9876125454902649},
#  {'label': 'positive', 'score': 0.9765645861625671},
#  {'label': 'positive', 'score': 0.9444298148155212},
#  {'label': 'positive', 'score': 0.9700616598129272},
#  {'label': 'negative', 'score': 0.9889585971832275},
#  {'label': 'positive', 'score': 0.7429500818252563},
#  {'label': 'positive', 'score': 0.9827840328216553},
#  {'label': 'positive', 'score': 0.9865747094154358},
#  {'label': 'positive', 'score': 0.9867842197418213},
#  {'label': 'positive', 'score': 0.9868142604827881},
#  {'label': 'positive', 'score': 0.9869084358215332},
#  {'label': 'positive', 'score': 0.9871023297309875},
#  {'label': 'positive', 'score': 0.9855108261108398},
#  {'label': 'positive', 'score': 0.987014889717102},
#  {'label': 'positive', 'score': 0.9870239496231079},
#  {'label': 'positive', 'score': 0.9872379302978516},
#  {'label': 'positive', 'score': 0.9841952323913574},
#  {'label': 'positive', 'score': 0.9427915811538696},
#  {'label': 'neutral', 'score': 0.994247317314148},
#  {'label': 'positive', 'score': 0.980393648147583},
#  {'label': 'positive', 'score': 0.9867231249809265},
#  {'label': 'positive', 'score': 0.9884620904922485},
#  {'label': 'positive', 'score': 0.9724674224853516},
#  {'label': 'negative', 'score': 0.9885595440864563},
#  {'label': 'negative', 'score': 0.9836623072624207},
#  {'label': 'negative', 'score': 0.9761048555374146},
#  {'label': 'negative', 'score': 0.9836703538894653},
#  {'label': 'negative', 'score': 0.9809085130691528},
#  {'label': 'negative', 'score': 0.9620320796966553},
#  {'label': 'positive', 'score': 0.952562153339386},
#  {'label': 'positive', 'score': 0.9579450488090515},
#  {'label': 'positive', 'score': 0.9821310043334961},
#  {'label': 'positive', 'score': 0.9843926429748535},
#  {'label': 'positive', 'score': 0.979056715965271},
#  {'label': 'positive', 'score': 0.9849866032600403},
#  {'label': 'neutral', 'score': 0.8169628381729126},
#  {'label': 'positive', 'score': 0.9616588950157166},
#  {'label': 'positive', 'score': 0.9871499538421631},
#  {'label': 'positive', 'score': 0.9574225544929504},
#  {'label': 'positive', 'score': 0.9860011339187622},
#  {'label': 'positive', 'score': 0.9850437641143799},
#  {'label': 'positive', 'score': 0.9813945293426514},
#  {'label': 'positive', 'score': 0.9807697534561157},
#  {'label': 'positive', 'score': 0.9861975312232971},
#  {'label': 'positive', 'score': 0.9869982004165649},
#  {'label': 'positive', 'score': 0.9853478074073792},
#  {'label': 'positive', 'score': 0.9842416644096375},
#  {'label': 'positive', 'score': 0.9871940016746521},
#  {'label': 'positive', 'score': 0.9676075577735901},
#  {'label': 'positive', 'score': 0.9728785157203674},
#  {'label': 'positive', 'score': 0.9846490025520325},
#  {'label': 'positive', 'score': 0.984328031539917},
#  {'label': 'positive', 'score': 0.9484468102455139},
#  {'label': 'positive', 'score': 0.9859447479248047},
#  {'label': 'positive', 'score': 0.9843496680259705},
#  {'label': 'positive', 'score': 0.9841183423995972},
#  {'label': 'positive', 'score': 0.9809790849685669},
#  {'label': 'neutral', 'score': 0.973075807094574},
#  {'label': 'positive', 'score': 0.9799455404281616},
#  {'label': 'positive', 'score': 0.9844632148742676},
#  {'label': 'positive', 'score': 0.9858814477920532},
#  {'label': 'positive', 'score': 0.9842133522033691},
#  {'label': 'positive', 'score': 0.98553466796875},
#  {'label': 'positive', 'score': 0.97950279712677},
#  {'label': 'positive', 'score': 0.9820228219032288},
#  {'label': 'positive', 'score': 0.9826580882072449},
#  {'label': 'positive', 'score': 0.9866639375686646},
#  {'label': 'positive', 'score': 0.9849692583084106},
#  {'label': 'positive', 'score': 0.9855741858482361},
#  {'label': 'positive', 'score': 0.9873223900794983},
#  {'label': 'positive', 'score': 0.9874901175498962},
#  {'label': 'positive', 'score': 0.9784981608390808},
#  {'label': 'positive', 'score': 0.9641882181167603},
#  {'label': 'positive', 'score': 0.9870265126228333},
#  {'label': 'positive', 'score': 0.9803152084350586},
#  {'label': 'positive', 'score': 0.985116183757782},
#  {'label': 'positive', 'score': 0.9874796271324158},
#  {'label': 'positive', 'score': 0.9770408272743225},
#  {'label': 'positive', 'score': 0.9837115406990051},
#  {'label': 'neutral', 'score': 0.9624700546264648},
#  {'label': 'neutral', 'score': 0.9728321433067322},
#  {'label': 'neutral', 'score': 0.9728321433067322},
#  {'label': 'positive', 'score': 0.9497009515762329},
#  {'label': 'positive', 'score': 0.9847837686538696},
#  {'label': 'positive', 'score': 0.9841704368591309},
#  {'label': 'positive', 'score': 0.9788090586662292},
#  {'label': 'positive', 'score': 0.9825873970985413},
#  {'label': 'positive', 'score': 0.9776651859283447},
#  {'label': 'positive', 'score': 0.9790956974029541},
#  {'label': 'positive', 'score': 0.9793177843093872},
#  {'label': 'positive', 'score': 0.9863393306732178},
#  {'label': 'positive', 'score': 0.9454960227012634},
#  {'label': 'positive', 'score': 0.9694104194641113},
#  {'label': 'positive', 'score': 0.9823620915412903},
#  {'label': 'positive', 'score': 0.8407948613166809},
#  {'label': 'positive', 'score': 0.9825824499130249},
#  {'label': 'positive', 'score': 0.9821182489395142},
#  {'label': 'positive', 'score': 0.9154787659645081},
#  {'label': 'positive', 'score': 0.977933943271637},
#  {'label': 'positive', 'score': 0.9826040863990784},
#  {'label': 'positive', 'score': 0.9841049313545227},
#  {'label': 'positive', 'score': 0.9858346581459045},
#  {'label': 'positive', 'score': 0.983965277671814},
#  {'label': 'positive', 'score': 0.9834876656532288},
#  {'label': 'positive', 'score': 0.9860759377479553},
#  {'label': 'positive', 'score': 0.9889281988143921},
#  {'label': 'positive', 'score': 0.9864091873168945},
#  {'label': 'neutral', 'score': 0.501394510269165},
#  {'label': 'positive', 'score': 0.988166093826294},
#  {'label': 'positive', 'score': 0.985042929649353},
#  {'label': 'positive', 'score': 0.8760294318199158},
#  {'label': 'positive', 'score': 0.9813050627708435},
#  {'label': 'positive', 'score': 0.9780201315879822},
#  {'label': 'positive', 'score': 0.9846953749656677},
#  {'label': 'neutral', 'score': 0.884354293346405},
#  {'label': 'positive', 'score': 0.9875164031982422},
#  {'label': 'positive', 'score': 0.9810864329338074},
#  {'label': 'positive', 'score': 0.6274077296257019},
#  {'label': 'positive', 'score': 0.9836068153381348},
#  {'label': 'positive', 'score': 0.9825769066810608},
#  {'label': 'positive', 'score': 0.9847884178161621},
#  {'label': 'positive', 'score': 0.9846071600914001},
#  {'label': 'positive', 'score': 0.9776665568351746},
#  {'label': 'positive', 'score': 0.9878518581390381},
#  {'label': 'positive', 'score': 0.983196496963501},
#  {'label': 'positive', 'score': 0.9854926466941833},
#  {'label': 'positive', 'score': 0.9859495759010315},
#  {'label': 'positive', 'score': 0.9810309410095215},
#  {'label': 'positive', 'score': 0.9559406042098999},
#  {'label': 'positive', 'score': 0.9818665385246277},
#  {'label': 'positive', 'score': 0.9802473783493042},
#  {'label': 'positive', 'score': 0.9831815361976624},
#  {'label': 'positive', 'score': 0.8735913038253784},
#  {'label': 'positive', 'score': 0.9599797129631042},
#  {'label': 'positive', 'score': 0.9738661050796509},
#  {'label': 'positive', 'score': 0.9877113699913025},
#  {'label': 'positive', 'score': 0.9492940902709961},
#  {'label': 'positive', 'score': 0.9783676266670227},
#  {'label': 'positive', 'score': 0.979314923286438},
#  {'label': 'positive', 'score': 0.9750024676322937},
#  {'label': 'positive', 'score': 0.9676858186721802},
#  {'label': 'positive', 'score': 0.9795580506324768},
#  {'label': 'positive', 'score': 0.9827045798301697},
#  {'label': 'positive', 'score': 0.9817988276481628},
#  {'label': 'neutral', 'score': 0.9575270414352417},
#  {'label': 'positive', 'score': 0.8568586111068726},
#  {'label': 'positive', 'score': 0.9326043128967285},
#  {'label': 'neutral', 'score': 0.967985212802887},
#  {'label': 'positive', 'score': 0.9853278994560242},
#  {'label': 'positive', 'score': 0.8583844304084778},
#  {'label': 'positive', 'score': 0.9779971241950989},
#  {'label': 'positive', 'score': 0.9854387044906616},
#  {'label': 'positive', 'score': 0.9828979969024658},
#  {'label': 'positive', 'score': 0.9832247495651245},
#  {'label': 'positive', 'score': 0.9805938601493835},
#  {'label': 'positive', 'score': 0.9854810833930969},
#  {'label': 'positive', 'score': 0.9812939763069153},
#  {'label': 'neutral', 'score': 0.9922817349433899},
#  {'label': 'neutral', 'score': 0.9659468531608582},
#  {'label': 'positive', 'score': 0.9801052212715149},
#  {'label': 'positive', 'score': 0.9445842504501343},
#  {'label': 'neutral', 'score': 0.9863206744194031},
#  {'label': 'positive', 'score': 0.9746923446655273},
#  {'label': 'positive', 'score': 0.986790120601654},
#  {'label': 'positive', 'score': 0.9852096438407898},
#  {'label': 'positive', 'score': 0.9767226576805115},
#  {'label': 'positive', 'score': 0.978217601776123},
#  {'label': 'positive', 'score': 0.9852756261825562},
#  {'label': 'positive', 'score': 0.8132949471473694},
#  {'label': 'positive', 'score': 0.9786083102226257},
#  {'label': 'positive', 'score': 0.9875479936599731},
#  {'label': 'positive', 'score': 0.9870781898498535},
#  {'label': 'positive', 'score': 0.9847474694252014},
#  {'label': 'positive', 'score': 0.9817066788673401},
#  {'label': 'positive', 'score': 0.9562891721725464},
#  {'label': 'positive', 'score': 0.9870582222938538},
#  {'label': 'positive', 'score': 0.9856488704681396},
#  {'label': 'positive', 'score': 0.9618541598320007},
#  {'label': 'neutral', 'score': 0.9824845194816589},
#  {'label': 'positive', 'score': 0.9778881072998047},
#  {'label': 'positive', 'score': 0.9834066033363342},
#  {'label': 'positive', 'score': 0.9854394197463989},
#  {'label': 'positive', 'score': 0.9836974740028381},
#  {'label': 'positive', 'score': 0.9814460873603821},
#  {'label': 'positive', 'score': 0.9828258156776428},
#  {'label': 'positive', 'score': 0.9771061539649963},
#  {'label': 'positive', 'score': 0.9822302460670471},
#  {'label': 'positive', 'score': 0.9809951186180115},
#  {'label': 'positive', 'score': 0.9807416796684265},
#  {'label': 'positive', 'score': 0.9803885221481323},
#  {'label': 'positive', 'score': 0.8576955199241638},
#  {'label': 'positive', 'score': 0.8828461170196533},
#  {'label': 'positive', 'score': 0.9833321571350098},
#  {'label': 'positive', 'score': 0.982962965965271},
#  {'label': 'positive', 'score': 0.9830559492111206},
#  {'label': 'positive', 'score': 0.956059992313385},
#  {'label': 'positive', 'score': 0.9853842854499817},
#  {'label': 'positive', 'score': 0.9719622731208801},
#  {'label': 'positive', 'score': 0.9865378141403198},
#  {'label': 'positive', 'score': 0.6032892465591431},
#  {'label': 'positive', 'score': 0.9866881966590881},
#  {'label': 'positive', 'score': 0.9708249568939209},
#  {'label': 'positive', 'score': 0.9773892164230347},
#  {'label': 'positive', 'score': 0.8243964314460754},
#  {'label': 'positive', 'score': 0.9681609272956848},
#  {'label': 'positive', 'score': 0.9855297207832336},
#  {'label': 'positive', 'score': 0.9861860275268555},
#  {'label': 'positive', 'score': 0.8937908411026001},
#  {'label': 'positive', 'score': 0.9065902829170227},
#  {'label': 'positive', 'score': 0.9727950096130371},
#  {'label': 'positive', 'score': 0.9779992699623108},
#  {'label': 'positive', 'score': 0.9769085049629211},
#  {'label': 'positive', 'score': 0.9687674641609192},
#  {'label': 'positive', 'score': 0.9595692157745361},
#  {'label': 'positive', 'score': 0.9831588268280029},
#  {'label': 'positive', 'score': 0.9820465445518494},
#  {'label': 'positive', 'score': 0.9839732646942139},
#  {'label': 'positive', 'score': 0.9882974028587341},
#  {'label': 'positive', 'score': 0.9732391238212585},
#  {'label': 'positive', 'score': 0.9850983619689941},
#  {'label': 'positive', 'score': 0.9817579388618469},
#  {'label': 'positive', 'score': 0.9733018279075623},
#  {'label': 'positive', 'score': 0.9788333773612976},
#  {'label': 'positive', 'score': 0.9825128316879272},
#  {'label': 'positive', 'score': 0.9808827042579651},
#  {'label': 'positive', 'score': 0.9836013913154602},
#  {'label': 'positive', 'score': 0.9846065044403076},
#  {'label': 'positive', 'score': 0.9828200340270996},
#  {'label': 'positive', 'score': 0.9836233258247375},
#  {'label': 'positive', 'score': 0.9843674302101135},
#  {'label': 'positive', 'score': 0.9829748272895813},
#  {'label': 'positive', 'score': 0.9857900738716125},
#  {'label': 'positive', 'score': 0.9533572793006897},
#  {'label': 'positive', 'score': 0.8545619249343872},
#  {'label': 'positive', 'score': 0.9829248785972595},
#  {'label': 'positive', 'score': 0.9820635318756104},
#  {'label': 'positive', 'score': 0.9627841114997864},
#  {'label': 'positive', 'score': 0.9849370121955872},
#  {'label': 'positive', 'score': 0.9859638214111328},
#  {'label': 'positive', 'score': 0.9815558791160583},
#  {'label': 'positive', 'score': 0.9848483204841614},
#  {'label': 'positive', 'score': 0.9664125442504883},
#  {'label': 'positive', 'score': 0.9826765060424805},
#  {'label': 'neutral', 'score': 0.9945091605186462},
#  {'label': 'positive', 'score': 0.9777928590774536},
#  {'label': 'neutral', 'score': 0.9572204351425171},
#  {'label': 'positive', 'score': 0.9854092001914978},
#  {'label': 'positive', 'score': 0.9317023158073425},
#  {'label': 'positive', 'score': 0.9852882027626038},
#  {'label': 'positive', 'score': 0.9851829409599304},
#  {'label': 'positive', 'score': 0.9861738681793213},
#  {'label': 'positive', 'score': 0.9883900880813599},
#  {'label': 'positive', 'score': 0.9868850708007812},
#  {'label': 'positive', 'score': 0.9866798520088196},
#  {'label': 'positive', 'score': 0.9865466356277466},
#  {'label': 'positive', 'score': 0.9770081043243408},
#  {'label': 'positive', 'score': 0.9885441660881042},
#  {'label': 'positive', 'score': 0.9871768355369568},
#  {'label': 'positive', 'score': 0.983423113822937},
#  {'label': 'positive', 'score': 0.9868510365486145},
#  {'label': 'positive', 'score': 0.9863921403884888},
#  {'label': 'positive', 'score': 0.9876535534858704},
#  {'label': 'positive', 'score': 0.9838809967041016},
#  {'label': 'positive', 'score': 0.9744601249694824},
#  {'label': 'positive', 'score': 0.9816719889640808},
#  {'label': 'positive', 'score': 0.9856211543083191},
#  {'label': 'positive', 'score': 0.9828253388404846},
#  {'label': 'positive', 'score': 0.9834499955177307},
#  {'label': 'positive', 'score': 0.9860917925834656},
#  {'label': 'positive', 'score': 0.9853627681732178},
#  {'label': 'neutral', 'score': 0.9870384931564331},
#  {'label': 'positive', 'score': 0.9852832555770874},
#  {'label': 'positive', 'score': 0.9834170937538147},
#  {'label': 'positive', 'score': 0.9835972189903259},
#  {'label': 'positive', 'score': 0.9827273488044739},
#  {'label': 'positive', 'score': 0.9825384616851807},
#  {'label': 'positive', 'score': 0.9831573367118835},
#  {'label': 'positive', 'score': 0.9679183959960938},
#  {'label': 'positive', 'score': 0.9650312066078186},
#  {'label': 'positive', 'score': 0.9837408661842346},
#  {'label': 'positive', 'score': 0.9602015614509583},
#  {'label': 'positive', 'score': 0.9849883317947388},
#  {'label': 'positive', 'score': 0.9749309420585632},
#  {'label': 'positive', 'score': 0.9596596956253052},
#  {'label': 'positive', 'score': 0.9740355014801025},
#  {'label': 'neutral', 'score': 0.9529387950897217},
#  {'label': 'positive', 'score': 0.9828453660011292},
#  {'label': 'positive', 'score': 0.9829441905021667},
#  {'label': 'positive', 'score': 0.9846118092536926},
#  {'label': 'positive', 'score': 0.9874765276908875},
#  {'label': 'neutral', 'score': 0.9874563813209534},
#  {'label': 'positive', 'score': 0.9754223823547363},
#  ...]

# %%
df
# Out:
#         result                                            content
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
df['sentiment'] = [r['label'] for r in results]
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_true = df['result']
y_pred = df['sentiment']

cm = confusion_matrix(y_true, y_pred)

sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
# Out:
# <Axes: >

# %%
df
# Out:
#         result                                            content sentiment
# 0      neutral  According to Gran , the company has no plans t...   neutral
# 1      neutral  Technopolis plans to develop in stages an area...   neutral
# 2     negative  The international electronic industry company ...  negative
# 3     positive  With the new production plant the company woul...  positive
# 4     positive  According to the company 's updated strategy f...  positive
# ...        ...                                                ...       ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  negative  Net sales of the Paper segment decreased to EU...  negative
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [4846 rows x 3 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9727610400330169
